# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
client_id = 'e738e985fed449e8846df5ee72139b87'
client_secret = '' 
# invalidated the previous one

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret):
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_token_headers(self):
        client_creds = f"{self.client_id}:{self.client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return {"Authorization": f"Basic {client_creds_b64.decode()}"}
    
    def get_token_data(self):
        return {"grant_type": "client_credentials"}
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            return False
        token_response_data = r.json()
        now = datetime.datetime.now()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        auth_done = self.perform_auth()
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, _id, resource_type="albums"):
        endpoint = f"https://api.spotify.com/v1/{resource_type}/{_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist'):
        headers = self.get_resource_header()
        url = "https://api.spotify.com/v1/search"
        data = urlencode({
            "q": "Blank Space", 
            "type": "track"
        })

        lookup_url = f"{url}?{data}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
client.search("Time", search_type="Track")

# %%
client.get_artist("06HL4z0CvFAxyc27GXpf02")

# %%
client.get_album("2QJmrSgbdM35R67eoGQo4j")

# %%
url = "https://accounts.spotify.com/authorize?"
headers = urlencode({
    "client_id": client_id,
    "response_type": "code",
    "redirect_uri": "http://127.0.0.1:5000/callback"
})
new_url = f'{url}{headers}'
realHeaders = client.get_resource_header()
r = requests.get(new_url, realHeaders)

# %%
print(r.text)
# Out:
# <!DOCTYPE html>
# <html id="app" lang="en" dir="ltr" ng-csp ng-strict-di>
# <head>
#   <meta charset="utf-8">
#   <title ng-bind="(&#39;loginTitle&#39; | localize) + &#39; - Spotify&#39;">Spotify</title>
#   <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no">
#   <base href="/">
#   <link rel="icon" href="https://accounts.scdn.co/images/favicon.ace4d8543bbb017893402a1e9d1ac1fa.ico">
#   <link href="https://accounts.scdn.co/css/index.843d063c7d7c72e443ef.css" media="screen" rel="stylesheet">
#
#   <script defer src="https://accounts.scdn.co/js/index.843d063c7d7c72e443ef.js" sp-bootstrap></script>
#   <meta ng-non-bindable sp-bootstrap-data='{"phoneFeatureEnabled":false,"previewEnabled":false,"user":false,"tpaState":"...","BON":["0","0",-1383303516]}'>
# </head>
# <body ng-controller="LoginController">
#   <div ng-include="template"></div>
# </body>
# </html>

# %%
auth_code = 'AQBE2LsoIEsWiBMjEBgh16BWAdUf-FGBUmmPMHsIVe6Mui8VO6UQcDm0-4wRJGG4UXqYu-lmhmk-nVV7QXeWH8v4A4jjD-vjbJCXQXNpznkO6Td3v5ttCy39B2YRbGBWKwNGawyBQ3d2L0Jv9ZiBI71MNHnbeoA65GYggpEY801qGQ'
data = {
    'grant_type': 'authorization_code',
    'code': auth_code,
    'redirect_uri': 'http://127.0.0.1:5000/callback'
}
headers = client.get_token_headers()
r = requests.post(url, data=data, headers=headers)

# %%
test = r.json()
print(test)
# Out:
# {'access_token': 'BQC0kOfZw-yFRJarecDED3WK8o94DiPekyItXHAakWJpxKITLKVcS-2Jb0rK8PIwjZM4kwACsfuyoW1Yweo8VlbzEsfcNzNDliDKOIpG1zvfB16Ktk362oy5tteVSSF9ohKDtwsQlkS0Itf-lK8q', 'token_type': 'Bearer', 'expires_in': 3600, 'refresh_token': 'AQAIHzkgowo8IX757yqUYMlqVniXkfbwQ12r4TFDT30VjMQY7WmyHQXbHTA7rWmy7uiX-hya7UR7lf6czUDPRPwQhSEqS5gVulxj9H6Lw1YXRRebNEeFr8ES0mqrytXIYz8', 'scope': ''}

# %%
url = 'https://accounts.spotify.com/api/token'
refresh_token = 'AQAGPJDESNsvAu0k7fw2c1RFd07YGpyGyJkxOQmkoB0BEhacgwlDcUDVMeI6240LWgb4Ed21fnWofVmBfyJSsyMYgp5ukv_go6dUB1HD3FRi65qO29dIAvHdWFdMAp8nVEI'
data = {
    'grant_type': 'refresh_token',
    'refresh_token': refresh_token,
}
headers = client.get_token_headers()
r = requests.post(url, data=data, headers=headers)

# %%
print(r.text)
# Out:
# {"access_token":"BQCK9jLn4lKb-5H1ouuZ0X0Z-KtO4o-smpnTMJ5j2pyqMnSRihhY28pIZQApuSc70J1mWSdTLrZcu_cd7NG7hfVF2FVO_QZWT6ivunwDQrdjW1Cth0LrKsmOv3WwuZjo44YzGwrXw99oiZwV8VWzFHBsuwgl","token_type":"Bearer","expires_in":3600,"scope":"user-top-read"}

# %%
url = "https://api.spotify.com/v1/me/top/tracks"
access_token = 'BQA8heRmBNNVdkVfrkZwzrxeZUyBL416gw7Sc7cIWZG-XVI8QRDTj5CXCK9c7wRV5W6cfncmD1WSVdVug2o5meoQbngQtl_TMnQueu3cPWwAxQLk1BmrR6ZC6rqcoZcrXlx2WapZKmERu205nWbypvdwdJ2Z'
headers = {
    'Authorization': f'Bearer {access_token}',
}
r = requests.get(url, headers=headers)
print(r)
# Out:
# <Response [200]>

# %%
print(r.text)
# Out:
# {
#   "items" : [ {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3JDG63cSaK3xgDnB2H55Xp"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3JDG63cSaK3xgDnB2H55Xp",
#         "id" : "3JDG63cSaK3xgDnB2H55Xp",
#         "name" : "Audrey Mika",
#         "type" : "artist",
#         "uri" : "spotify:artist:3JDG63cSaK3xgDnB2H55Xp"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/0J9VlRE4GIO7EDkYkIl8YL"
#       },
#       "href" : "https://api.spotify.com/v1/albums/0J9VlRE4GIO7EDkYkIl8YL",
#       "id" : "0J9VlRE4GIO7EDkYkIl8YL",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2739d52163735bf12ebc22e334b",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e029d52163735bf12ebc22e334b",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048519d52163735bf12ebc22e334b",
#         "width" : 64
#       } ],
#       "name" : "Just Friends",
#       "release_date" : "2020-05-08",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:0J9VlRE4GIO7EDkYkIl8YL"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/3JDG63cSaK3xgDnB2H55Xp"
#       },
#       "href" : "https://api.spotify.com/v1/artists/3JDG63cSaK3xgDnB2H55Xp",
#       "id" : "3JDG63cSaK3xgDnB2H55Xp",
#       "name" : "Audrey Mika",
#       "type" : "artist",
#       "uri" : "spotify:artist:3JDG63cSaK3xgDnB2H55Xp"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 168982,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USRC12001074"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/1NzRZ7AosK7ZDumMsZYofo"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/1NzRZ7AosK7ZDumMsZYofo",
#     "id" : "1NzRZ7AosK7ZDumMsZYofo",
#     "is_local" : false,
#     "name" : "Just Friends",
#     "popularity" : 67,
#     "preview_url" : "https://p.scdn.co/mp3-preview/e1998c3b06dc49c7298e186e2f3ab6c489805f71?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:1NzRZ7AosK7ZDumMsZYofo"
#   }, {
#     "album" : {
#       "album_type" : "ALBUM",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/6DIS6PRrLS3wbnZsf7vYic"
#         },
#         "href" : "https://api.spotify.com/v1/artists/6DIS6PRrLS3wbnZsf7vYic",
#         "id" : "6DIS6PRrLS3wbnZsf7vYic",
#         "name" : "WALK THE MOON",
#         "type" : "artist",
#         "uri" : "spotify:artist:6DIS6PRrLS3wbnZsf7vYic"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/4fe1YmssM6Ugs6UyA7OdGg"
#       },
#       "href" : "https://api.spotify.com/v1/albums/4fe1YmssM6Ugs6UyA7OdGg",
#       "id" : "4fe1YmssM6Ugs6UyA7OdGg",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273ffbb5bd9ea83111033066254",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e02ffbb5bd9ea83111033066254",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d00004851ffbb5bd9ea83111033066254",
#         "width" : 64
#       } ],
#       "name" : "What If Nothing",
#       "release_date" : "2017-11-10",
#       "release_date_precision" : "day",
#       "total_tracks" : 13,
#       "type" : "album",
#       "uri" : "spotify:album:4fe1YmssM6Ugs6UyA7OdGg"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/6DIS6PRrLS3wbnZsf7vYic"
#       },
#       "href" : "https://api.spotify.com/v1/artists/6DIS6PRrLS3wbnZsf7vYic",
#       "id" : "6DIS6PRrLS3wbnZsf7vYic",
#       "name" : "WALK THE MOON",
#       "type" : "artist",
#       "uri" : "spotify:artist:6DIS6PRrLS3wbnZsf7vYic"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 235960,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USRC11702175"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/0M1A9wInEHilyWkh4I8tWo"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/0M1A9wInEHilyWkh4I8tWo",
#     "id" : "0M1A9wInEHilyWkh4I8tWo",
#     "is_local" : false,
#     "name" : "Lost In The Wild",
#     "popularity" : 74,
#     "preview_url" : "https://p.scdn.co/mp3-preview/48e4c5dd704b46b831c8f1e1c76647d26bbd942e?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 13,
#     "type" : "track",
#     "uri" : "spotify:track:0M1A9wInEHilyWkh4I8tWo"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/4vxaQs6vK54nK89J1VtLex"
#         },
#         "href" : "https://api.spotify.com/v1/artists/4vxaQs6vK54nK89J1VtLex",
#         "id" : "4vxaQs6vK54nK89J1VtLex",
#         "name" : "PUBLIC",
#         "type" : "artist",
#         "uri" : "spotify:artist:4vxaQs6vK54nK89J1VtLex"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/2CxrZinzjDXZidyx5EP214"
#       },
#       "href" : "https://api.spotify.com/v1/albums/2CxrZinzjDXZidyx5EP214",
#       "id" : "2CxrZinzjDXZidyx5EP214",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2730d0621554b1c6c9dbf3556be",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e020d0621554b1c6c9dbf3556be",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048510d0621554b1c6c9dbf3556be",
#         "width" : 64
#       } ],
#       "name" : "Make You Mine",
#       "release_date" : "2019-08-09",
#       "release_date_precision" : "day",
#       "total_tracks" : 3,
#       "type" : "album",
#       "uri" : "spotify:album:2CxrZinzjDXZidyx5EP214"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/4vxaQs6vK54nK89J1VtLex"
#       },
#       "href" : "https://api.spotify.com/v1/artists/4vxaQs6vK54nK89J1VtLex",
#       "id" : "4vxaQs6vK54nK89J1VtLex",
#       "name" : "PUBLIC",
#       "type" : "artist",
#       "uri" : "spotify:artist:4vxaQs6vK54nK89J1VtLex"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 232906,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "TCACE1578479"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/5iFwAOB2TFkPJk8sMlxP8g"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/5iFwAOB2TFkPJk8sMlxP8g",
#     "id" : "5iFwAOB2TFkPJk8sMlxP8g",
#     "is_local" : false,
#     "name" : "Make You Mine",
#     "popularity" : 82,
#     "preview_url" : "https://p.scdn.co/mp3-preview/b03175563bf8617fb5ee6b8e22730ba9a21eec8d?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 2,
#     "type" : "track",
#     "uri" : "spotify:track:5iFwAOB2TFkPJk8sMlxP8g"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#         },
#         "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#         "id" : "45dkTj5sMRSjrmBSBeiHym",
#         "name" : "Tate McRae",
#         "type" : "artist",
#         "uri" : "spotify:artist:45dkTj5sMRSjrmBSBeiHym"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/1RWiRfdNZKDe8VXzzf2VEc"
#       },
#       "href" : "https://api.spotify.com/v1/albums/1RWiRfdNZKDe8VXzzf2VEc",
#       "id" : "1RWiRfdNZKDe8VXzzf2VEc",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2730c2c97099fd6a637ed0aa4a4",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e020c2c97099fd6a637ed0aa4a4",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048510c2c97099fd6a637ed0aa4a4",
#         "width" : 64
#       } ],
#       "name" : "you broke me first",
#       "release_date" : "2020-04-17",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:1RWiRfdNZKDe8VXzzf2VEc"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#       },
#       "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#       "id" : "45dkTj5sMRSjrmBSBeiHym",
#       "name" : "Tate McRae",
#       "type" : "artist",
#       "uri" : "spotify:artist:45dkTj5sMRSjrmBSBeiHym"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 169265,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USRC12000832"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/45bE4HXI0AwGZXfZtMp8JR"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/45bE4HXI0AwGZXfZtMp8JR",
#     "id" : "45bE4HXI0AwGZXfZtMp8JR",
#     "is_local" : false,
#     "name" : "you broke me first",
#     "popularity" : 94,
#     "preview_url" : "https://p.scdn.co/mp3-preview/47afb10323067e827310e5898e4d52c8bdbe72ee?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:45bE4HXI0AwGZXfZtMp8JR"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK"
#         },
#         "href" : "https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK",
#         "id" : "164Uj4eKjl6zTBKfJLFKKK",
#         "name" : "JVKE",
#         "type" : "artist",
#         "uri" : "spotify:artist:164Uj4eKjl6zTBKfJLFKKK"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/3zbwyRuqL8HYmRJdtcI4xL"
#       },
#       "href" : "https://api.spotify.com/v1/albums/3zbwyRuqL8HYmRJdtcI4xL",
#       "id" : "3zbwyRuqL8HYmRJdtcI4xL",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b27326bb212c82799e600b310789",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e0226bb212c82799e600b310789",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d0000485126bb212c82799e600b310789",
#         "width" : 64
#       } ],
#       "name" : "Upside Down",
#       "release_date" : "2020-08-18",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:3zbwyRuqL8HYmRJdtcI4xL"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/164Uj4eKjl6zTBKfJLFKKK"
#       },
#       "href" : "https://api.spotify.com/v1/artists/164Uj4eKjl6zTBKfJLFKKK",
#       "id" : "164Uj4eKjl6zTBKfJLFKKK",
#       "name" : "JVKE",
#       "type" : "artist",
#       "uri" : "spotify:artist:164Uj4eKjl6zTBKfJLFKKK"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 114500,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "QM24S2008283"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/614OkajfRPH8V0ugNQnduP"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/614OkajfRPH8V0ugNQnduP",
#     "id" : "614OkajfRPH8V0ugNQnduP",
#     "is_local" : false,
#     "name" : "Upside Down",
#     "popularity" : 81,
#     "preview_url" : "https://p.scdn.co/mp3-preview/3b5273dd51203d61e73fe5cc7311a10d1085631a?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:614OkajfRPH8V0ugNQnduP"
#   }, {
#     "album" : {
#       "album_type" : "ALBUM",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/2feDdbD5araYcm6JhFHHw7"
#         },
#         "href" : "https://api.spotify.com/v1/artists/2feDdbD5araYcm6JhFHHw7",
#         "id" : "2feDdbD5araYcm6JhFHHw7",
#         "name" : "Labrinth",
#         "type" : "artist",
#         "uri" : "spotify:artist:2feDdbD5araYcm6JhFHHw7"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/788r22Bhr3IHLTNPy8pZea"
#       },
#       "href" : "https://api.spotify.com/v1/albums/788r22Bhr3IHLTNPy8pZea",
#       "id" : "788r22Bhr3IHLTNPy8pZea",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b27389c39ba1acdf33ed7acd3867",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e0289c39ba1acdf33ed7acd3867",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d0000485189c39ba1acdf33ed7acd3867",
#         "width" : 64
#       } ],
#       "name" : "Euphoria (Original Score from the HBO Series)",
#       "release_date" : "2019-10-04",
#       "release_date_precision" : "day",
#       "total_tracks" : 26,
#       "type" : "album",
#       "uri" : "spotify:album:788r22Bhr3IHLTNPy8pZea"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/2feDdbD5araYcm6JhFHHw7"
#       },
#       "href" : "https://api.spotify.com/v1/artists/2feDdbD5araYcm6JhFHHw7",
#       "id" : "2feDdbD5araYcm6JhFHHw7",
#       "name" : "Labrinth",
#       "type" : "artist",
#       "uri" : "spotify:artist:2feDdbD5araYcm6JhFHHw7"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 153294,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USQX91902507"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/6N22FZs2ZhPBYi3b9XPajV"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/6N22FZs2ZhPBYi3b9XPajV",
#     "id" : "6N22FZs2ZhPBYi3b9XPajV",
#     "is_local" : false,
#     "name" : "Still Don't Know My Name",
#     "popularity" : 88,
#     "preview_url" : "https://p.scdn.co/mp3-preview/2f3df1d334b61c34fbf5e9baf75d5e02897c0964?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 12,
#     "type" : "track",
#     "uri" : "spotify:track:6N22FZs2ZhPBYi3b9XPajV"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/33crDRqANd3NQHJagZkQ7O"
#         },
#         "href" : "https://api.spotify.com/v1/artists/33crDRqANd3NQHJagZkQ7O",
#         "id" : "33crDRqANd3NQHJagZkQ7O",
#         "name" : "slchld",
#         "type" : "artist",
#         "uri" : "spotify:artist:33crDRqANd3NQHJagZkQ7O"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/6TIChvlc4qDxRxCJP7Ks4Z"
#       },
#       "href" : "https://api.spotify.com/v1/albums/6TIChvlc4qDxRxCJP7Ks4Z",
#       "id" : "6TIChvlc4qDxRxCJP7Ks4Z",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273be513a021eacf19c4ec44fe3",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e02be513a021eacf19c4ec44fe3",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d00004851be513a021eacf19c4ec44fe3",
#         "width" : 64
#       } ],
#       "name" : "my insecurities, not yours",
#       "release_date" : "2019-03-01",
#       "release_date_precision" : "day",
#       "total_tracks" : 4,
#       "type" : "album",
#       "uri" : "spotify:album:6TIChvlc4qDxRxCJP7Ks4Z"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/33crDRqANd3NQHJagZkQ7O"
#       },
#       "href" : "https://api.spotify.com/v1/artists/33crDRqANd3NQHJagZkQ7O",
#       "id" : "33crDRqANd3NQHJagZkQ7O",
#       "name" : "slchld",
#       "type" : "artist",
#       "uri" : "spotify:artist:33crDRqANd3NQHJagZkQ7O"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 207435,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "QZDA71918712"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/2sFF0K2eHIClZYUqIbAwdb"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/2sFF0K2eHIClZYUqIbAwdb",
#     "id" : "2sFF0K2eHIClZYUqIbAwdb",
#     "is_local" : false,
#     "name" : "she likes spring, I prefer winter",
#     "popularity" : 67,
#     "preview_url" : "https://p.scdn.co/mp3-preview/6f2f56f748764ae6e23a67ae673cd31bb319310d?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 2,
#     "type" : "track",
#     "uri" : "spotify:track:2sFF0K2eHIClZYUqIbAwdb"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/6chWbUfdu6ibyaCXM1w8kQ"
#         },
#         "href" : "https://api.spotify.com/v1/artists/6chWbUfdu6ibyaCXM1w8kQ",
#         "id" : "6chWbUfdu6ibyaCXM1w8kQ",
#         "name" : "Forrest.",
#         "type" : "artist",
#         "uri" : "spotify:artist:6chWbUfdu6ibyaCXM1w8kQ"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/67buolBsDm0XkJikkqZRxv"
#       },
#       "href" : "https://api.spotify.com/v1/albums/67buolBsDm0XkJikkqZRxv",
#       "id" : "67buolBsDm0XkJikkqZRxv",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273f5e52a266c7df184a323c639",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e02f5e52a266c7df184a323c639",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d00004851f5e52a266c7df184a323c639",
#         "width" : 64
#       } ],
#       "name" : "Backwards",
#       "release_date" : "2020-08-19",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:67buolBsDm0XkJikkqZRxv"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/6chWbUfdu6ibyaCXM1w8kQ"
#       },
#       "href" : "https://api.spotify.com/v1/artists/6chWbUfdu6ibyaCXM1w8kQ",
#       "id" : "6chWbUfdu6ibyaCXM1w8kQ",
#       "name" : "Forrest.",
#       "type" : "artist",
#       "uri" : "spotify:artist:6chWbUfdu6ibyaCXM1w8kQ"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 173253,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "QZJ842000458"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/3HL4n8vCeCyYLxogqkUxup"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/3HL4n8vCeCyYLxogqkUxup",
#     "id" : "3HL4n8vCeCyYLxogqkUxup",
#     "is_local" : false,
#     "name" : "Backwards",
#     "popularity" : 51,
#     "preview_url" : "https://p.scdn.co/mp3-preview/75d1aef8864469260b487330a3b9347806204e74?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:3HL4n8vCeCyYLxogqkUxup"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/4NZvixzsSefsNiIqXn0NDe"
#         },
#         "href" : "https://api.spotify.com/v1/artists/4NZvixzsSefsNiIqXn0NDe",
#         "id" : "4NZvixzsSefsNiIqXn0NDe",
#         "name" : "Maggie Rogers",
#         "type" : "artist",
#         "uri" : "spotify:artist:4NZvixzsSefsNiIqXn0NDe"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/47SKepdJ0B5cquxtKrgFUI"
#       },
#       "href" : "https://api.spotify.com/v1/albums/47SKepdJ0B5cquxtKrgFUI",
#       "id" : "47SKepdJ0B5cquxtKrgFUI",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2739e6e788c086495c0c0effce9",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e029e6e788c086495c0c0effce9",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048519e6e788c086495c0c0effce9",
#         "width" : 64
#       } ],
#       "name" : "Love You For A Long Time",
#       "release_date" : "2019-11-21",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:47SKepdJ0B5cquxtKrgFUI"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/4NZvixzsSefsNiIqXn0NDe"
#       },
#       "href" : "https://api.spotify.com/v1/artists/4NZvixzsSefsNiIqXn0NDe",
#       "id" : "4NZvixzsSefsNiIqXn0NDe",
#       "name" : "Maggie Rogers",
#       "type" : "artist",
#       "uri" : "spotify:artist:4NZvixzsSefsNiIqXn0NDe"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 223120,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USUG11903787"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/6QTPacyXkZWG9FMwq6L1hJ"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/6QTPacyXkZWG9FMwq6L1hJ",
#     "id" : "6QTPacyXkZWG9FMwq6L1hJ",
#     "is_local" : false,
#     "name" : "Love You For A Long Time",
#     "popularity" : 74,
#     "preview_url" : "https://p.scdn.co/mp3-preview/70583c6464c14305eefdbe3558410f87e656fa25?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:6QTPacyXkZWG9FMwq6L1hJ"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq",
#         "id" : "3MZsBdqDrRTJihTHQrO6Dq",
#         "name" : "Joji",
#         "type" : "artist",
#         "uri" : "spotify:artist:3MZsBdqDrRTJihTHQrO6Dq"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX"
#         },
#         "href" : "https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX",
#         "id" : "5fMUXHkw8R8eOP2RNVYEZX",
#         "name" : "Diplo",
#         "type" : "artist",
#         "uri" : "spotify:artist:5fMUXHkw8R8eOP2RNVYEZX"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/1jcNHi5D96aaD0T5f1OjFY"
#       },
#       "href" : "https://api.spotify.com/v1/albums/1jcNHi5D96aaD0T5f1OjFY",
#       "id" : "1jcNHi5D96aaD0T5f1OjFY",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2730e991b59cee17246a5e604d0",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e020e991b59cee17246a5e604d0",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048510e991b59cee17246a5e604d0",
#         "width" : 64
#       } ],
#       "name" : "Daylight",
#       "release_date" : "2020-08-06",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:1jcNHi5D96aaD0T5f1OjFY"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/3MZsBdqDrRTJihTHQrO6Dq"
#       },
#       "href" : "https://api.spotify.com/v1/artists/3MZsBdqDrRTJihTHQrO6Dq",
#       "id" : "3MZsBdqDrRTJihTHQrO6Dq",
#       "name" : "Joji",
#       "type" : "artist",
#       "uri" : "spotify:artist:3MZsBdqDrRTJihTHQrO6Dq"
#     }, {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/5fMUXHkw8R8eOP2RNVYEZX"
#       },
#       "href" : "https://api.spotify.com/v1/artists/5fMUXHkw8R8eOP2RNVYEZX",
#       "id" : "5fMUXHkw8R8eOP2RNVYEZX",
#       "name" : "Diplo",
#       "type" : "artist",
#       "uri" : "spotify:artist:5fMUXHkw8R8eOP2RNVYEZX"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 163905,
#     "explicit" : true,
#     "external_ids" : {
#       "isrc" : "USSM12004620"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/6Ed1q0X8oSKSm4IIhiQbYg"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/6Ed1q0X8oSKSm4IIhiQbYg",
#     "id" : "6Ed1q0X8oSKSm4IIhiQbYg",
#     "is_local" : false,
#     "name" : "Daylight",
#     "popularity" : 82,
#     "preview_url" : "https://p.scdn.co/mp3-preview/698a400b59f139ec6581c8538992bc7f51fec4b3?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:6Ed1q0X8oSKSm4IIhiQbYg"
#   }, {
#     "album" : {
#       "album_type" : "ALBUM",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1KP6TWI40m7p3QBTU6u2xo"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1KP6TWI40m7p3QBTU6u2xo",
#         "id" : "1KP6TWI40m7p3QBTU6u2xo",
#         "name" : "BØRNS",
#         "type" : "artist",
#         "uri" : "spotify:artist:1KP6TWI40m7p3QBTU6u2xo"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/17l7MIu0Jh0tdgK7or9ovw"
#       },
#       "href" : "https://api.spotify.com/v1/albums/17l7MIu0Jh0tdgK7or9ovw",
#       "id" : "17l7MIu0Jh0tdgK7or9ovw",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273cc2cf912462d8ae4ef856434",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e02cc2cf912462d8ae4ef856434",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d00004851cc2cf912462d8ae4ef856434",
#         "width" : 64
#       } ],
#       "name" : "Dopamine",
#       "release_date" : "2015-10-16",
#       "release_date_precision" : "day",
#       "total_tracks" : 11,
#       "type" : "album",
#       "uri" : "spotify:album:17l7MIu0Jh0tdgK7or9ovw"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/1KP6TWI40m7p3QBTU6u2xo"
#       },
#       "href" : "https://api.spotify.com/v1/artists/1KP6TWI40m7p3QBTU6u2xo",
#       "id" : "1KP6TWI40m7p3QBTU6u2xo",
#       "name" : "BØRNS",
#       "type" : "artist",
#       "uri" : "spotify:artist:1KP6TWI40m7p3QBTU6u2xo"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 218106,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USUM71416307"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/2GiJYvgVaD2HtM8GqD9EgQ"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/2GiJYvgVaD2HtM8GqD9EgQ",
#     "id" : "2GiJYvgVaD2HtM8GqD9EgQ",
#     "is_local" : false,
#     "name" : "Electric Love",
#     "popularity" : 87,
#     "preview_url" : "https://p.scdn.co/mp3-preview/eaab7f0c56f60b49304a8ec0579d2580c4df67e5?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 3,
#     "type" : "track",
#     "uri" : "spotify:track:2GiJYvgVaD2HtM8GqD9EgQ"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/1htYtUdXVMwR6HCSs821Lc"
#         },
#         "href" : "https://api.spotify.com/v1/artists/1htYtUdXVMwR6HCSs821Lc",
#         "id" : "1htYtUdXVMwR6HCSs821Lc",
#         "name" : "Avenue Beat",
#         "type" : "artist",
#         "uri" : "spotify:artist:1htYtUdXVMwR6HCSs821Lc"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/0UPr4kD3ZmC14EsT8XLagw"
#       },
#       "href" : "https://api.spotify.com/v1/albums/0UPr4kD3ZmC14EsT8XLagw",
#       "id" : "0UPr4kD3ZmC14EsT8XLagw",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2737f236f8468745c7e6f1a442f",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e027f236f8468745c7e6f1a442f",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048517f236f8468745c7e6f1a442f",
#         "width" : 64
#       } ],
#       "name" : "F2020",
#       "release_date" : "2020-08-14",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:0UPr4kD3ZmC14EsT8XLagw"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/1htYtUdXVMwR6HCSs821Lc"
#       },
#       "href" : "https://api.spotify.com/v1/artists/1htYtUdXVMwR6HCSs821Lc",
#       "id" : "1htYtUdXVMwR6HCSs821Lc",
#       "name" : "Avenue Beat",
#       "type" : "artist",
#       "uri" : "spotify:artist:1htYtUdXVMwR6HCSs821Lc"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 181851,
#     "explicit" : true,
#     "external_ids" : {
#       "isrc" : "USLXJ2044040"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/7opTGnWVJcm1e5mWWOldpg"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/7opTGnWVJcm1e5mWWOldpg",
#     "id" : "7opTGnWVJcm1e5mWWOldpg",
#     "is_local" : false,
#     "name" : "F2020",
#     "popularity" : 75,
#     "preview_url" : "https://p.scdn.co/mp3-preview/a30ac14dad3273c4c4adf188a33896956591a90e?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:7opTGnWVJcm1e5mWWOldpg"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3QJUFtGBGL05vo0kCJZsmT"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3QJUFtGBGL05vo0kCJZsmT",
#         "id" : "3QJUFtGBGL05vo0kCJZsmT",
#         "name" : "salem ilese",
#         "type" : "artist",
#         "uri" : "spotify:artist:3QJUFtGBGL05vo0kCJZsmT"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/1xWYSg7J7pxTZ113CJVy1P"
#       },
#       "href" : "https://api.spotify.com/v1/albums/1xWYSg7J7pxTZ113CJVy1P",
#       "id" : "1xWYSg7J7pxTZ113CJVy1P",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2731cb068e27f83975bc827586e",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e021cb068e27f83975bc827586e",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048511cb068e27f83975bc827586e",
#         "width" : 64
#       } ],
#       "name" : "Mad at Disney",
#       "release_date" : "2020-07-24",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:1xWYSg7J7pxTZ113CJVy1P"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/3QJUFtGBGL05vo0kCJZsmT"
#       },
#       "href" : "https://api.spotify.com/v1/artists/3QJUFtGBGL05vo0kCJZsmT",
#       "id" : "3QJUFtGBGL05vo0kCJZsmT",
#       "name" : "salem ilese",
#       "type" : "artist",
#       "uri" : "spotify:artist:3QJUFtGBGL05vo0kCJZsmT"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 136838,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "QMEZE2076989"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/7aGyRfJWtLqgJaZoG9lJhE"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/7aGyRfJWtLqgJaZoG9lJhE",
#     "id" : "7aGyRfJWtLqgJaZoG9lJhE",
#     "is_local" : false,
#     "name" : "Mad at Disney",
#     "popularity" : 89,
#     "preview_url" : "https://p.scdn.co/mp3-preview/2a1d9c96c39d7737bd000e6873a06f128b168121?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:7aGyRfJWtLqgJaZoG9lJhE"
#   }, {
#     "album" : {
#       "album_type" : "ALBUM",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02"
#         },
#         "href" : "https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02",
#         "id" : "06HL4z0CvFAxyc27GXpf02",
#         "name" : "Taylor Swift",
#         "type" : "artist",
#         "uri" : "spotify:artist:06HL4z0CvFAxyc27GXpf02"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/2fenSS68JI1h4Fo296JfGr"
#       },
#       "href" : "https://api.spotify.com/v1/albums/2fenSS68JI1h4Fo296JfGr",
#       "id" : "2fenSS68JI1h4Fo296JfGr",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b27395f754318336a07e85ec59bc",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e0295f754318336a07e85ec59bc",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d0000485195f754318336a07e85ec59bc",
#         "width" : 64
#       } ],
#       "name" : "folklore",
#       "release_date" : "2020-07-24",
#       "release_date_precision" : "day",
#       "total_tracks" : 16,
#       "type" : "album",
#       "uri" : "spotify:album:2fenSS68JI1h4Fo296JfGr"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02"
#       },
#       "href" : "https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02",
#       "id" : "06HL4z0CvFAxyc27GXpf02",
#       "name" : "Taylor Swift",
#       "type" : "artist",
#       "uri" : "spotify:artist:06HL4z0CvFAxyc27GXpf02"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 234000,
#     "explicit" : true,
#     "external_ids" : {
#       "isrc" : "USUG12002849"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/7MbT4I8qGntX4fMdqMQgke"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/7MbT4I8qGntX4fMdqMQgke",
#     "id" : "7MbT4I8qGntX4fMdqMQgke",
#     "is_local" : false,
#     "name" : "peace",
#     "popularity" : 74,
#     "preview_url" : "https://p.scdn.co/mp3-preview/70a0ab93ca5f4fa418176b622da87231216110a9?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 15,
#     "type" : "track",
#     "uri" : "spotify:track:7MbT4I8qGntX4fMdqMQgke"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#         },
#         "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#         "id" : "45dkTj5sMRSjrmBSBeiHym",
# ...
#     "disc_number" : 1,
#     "duration_ms" : 175813,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "KRA402000131"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/2J4P46vCFm1rPkNkp9pZWX"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/2J4P46vCFm1rPkNkp9pZWX",
#     "id" : "2J4P46vCFm1rPkNkp9pZWX",
#     "is_local" : false,
#     "name" : "Ice Cream (with Selena Gomez)",
#     "popularity" : 86,
#     "preview_url" : "https://p.scdn.co/mp3-preview/81bb538bdbafde3a49e78821de67261d5e51b03c?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:2J4P46vCFm1rPkNkp9pZWX"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#         },
#         "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#         "id" : "45dkTj5sMRSjrmBSBeiHym",
#         "name" : "Tate McRae",
#         "type" : "artist",
#         "uri" : "spotify:artist:45dkTj5sMRSjrmBSBeiHym"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/0uzAVFqstsfwdLtnDs6zm8"
#       },
#       "href" : "https://api.spotify.com/v1/albums/0uzAVFqstsfwdLtnDs6zm8",
#       "id" : "0uzAVFqstsfwdLtnDs6zm8",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b2738d61a6d821636c7f855fb17e",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e028d61a6d821636c7f855fb17e",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d000048518d61a6d821636c7f855fb17e",
#         "width" : 64
#       } ],
#       "name" : "stupid",
#       "release_date" : "2019-12-06",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:0uzAVFqstsfwdLtnDs6zm8"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#       },
#       "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#       "id" : "45dkTj5sMRSjrmBSBeiHym",
#       "name" : "Tate McRae",
#       "type" : "artist",
#       "uri" : "spotify:artist:45dkTj5sMRSjrmBSBeiHym"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 172915,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "USRC11903366"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/4k3uABcX9iaGlt5pRJhumi"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/4k3uABcX9iaGlt5pRJhumi",
#     "id" : "4k3uABcX9iaGlt5pRJhumi",
#     "is_local" : false,
#     "name" : "stupid",
#     "popularity" : 77,
#     "preview_url" : "https://p.scdn.co/mp3-preview/b56e9d89da806d33126a6794a25e4616d364775d?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:4k3uABcX9iaGlt5pRJhumi"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/7z1VrrLktQYoS9C0cFbfnI"
#         },
#         "href" : "https://api.spotify.com/v1/artists/7z1VrrLktQYoS9C0cFbfnI",
#         "id" : "7z1VrrLktQYoS9C0cFbfnI",
#         "name" : "Tatiana Manaois",
#         "type" : "artist",
#         "uri" : "spotify:artist:7z1VrrLktQYoS9C0cFbfnI"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/6BI6vwdUODKDu40EgalaAh"
#       },
#       "href" : "https://api.spotify.com/v1/albums/6BI6vwdUODKDu40EgalaAh",
#       "id" : "6BI6vwdUODKDu40EgalaAh",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273bc122d0dcab44bc7f4dffb47",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e02bc122d0dcab44bc7f4dffb47",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d00004851bc122d0dcab44bc7f4dffb47",
#         "width" : 64
#       } ],
#       "name" : "Your Ocean",
#       "release_date" : "2020-08-05",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:6BI6vwdUODKDu40EgalaAh"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/7z1VrrLktQYoS9C0cFbfnI"
#       },
#       "href" : "https://api.spotify.com/v1/artists/7z1VrrLktQYoS9C0cFbfnI",
#       "id" : "7z1VrrLktQYoS9C0cFbfnI",
#       "name" : "Tatiana Manaois",
#       "type" : "artist",
#       "uri" : "spotify:artist:7z1VrrLktQYoS9C0cFbfnI"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 131041,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "QZK6P2019894"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/6WerZ9Yyvwuns3lOMkHTbX"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/6WerZ9Yyvwuns3lOMkHTbX",
#     "id" : "6WerZ9Yyvwuns3lOMkHTbX",
#     "is_local" : false,
#     "name" : "Your Ocean",
#     "popularity" : 41,
#     "preview_url" : "https://p.scdn.co/mp3-preview/3465725c72a113904dcf5f7751c402969c7b5b74?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:6WerZ9Yyvwuns3lOMkHTbX"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3MNLhvqJkWsO6tcjY9ps62"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3MNLhvqJkWsO6tcjY9ps62",
#         "id" : "3MNLhvqJkWsO6tcjY9ps62",
#         "name" : "Maude Latour",
#         "type" : "artist",
#         "uri" : "spotify:artist:3MNLhvqJkWsO6tcjY9ps62"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/17tA1j7iaCKHDjXhW2cpkI"
#       },
#       "href" : "https://api.spotify.com/v1/albums/17tA1j7iaCKHDjXhW2cpkI",
#       "id" : "17tA1j7iaCKHDjXhW2cpkI",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b27314f4fd257eac618e8c5f8635",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e0214f4fd257eac618e8c5f8635",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d0000485114f4fd257eac618e8c5f8635",
#         "width" : 64
#       } ],
#       "name" : "One More Weekend",
#       "release_date" : "2020-07-24",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:17tA1j7iaCKHDjXhW2cpkI"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/3MNLhvqJkWsO6tcjY9ps62"
#       },
#       "href" : "https://api.spotify.com/v1/artists/3MNLhvqJkWsO6tcjY9ps62",
#       "id" : "3MNLhvqJkWsO6tcjY9ps62",
#       "name" : "Maude Latour",
#       "type" : "artist",
#       "uri" : "spotify:artist:3MNLhvqJkWsO6tcjY9ps62"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 142829,
#     "explicit" : false,
#     "external_ids" : {
#       "isrc" : "QZC5P1800248"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/5CXCo9MJFpjFLkEFKaMz19"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/5CXCo9MJFpjFLkEFKaMz19",
#     "id" : "5CXCo9MJFpjFLkEFKaMz19",
#     "is_local" : false,
#     "name" : "One More Weekend",
#     "popularity" : 56,
#     "preview_url" : "https://p.scdn.co/mp3-preview/d326d4d914c93e418d0c9fe9f7f13f249805f0fd?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:5CXCo9MJFpjFLkEFKaMz19"
#   }, {
#     "album" : {
#       "album_type" : "SINGLE",
#       "artists" : [ {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/6y5amJcTjeDgLXIjtQLMst"
#         },
#         "href" : "https://api.spotify.com/v1/artists/6y5amJcTjeDgLXIjtQLMst",
#         "id" : "6y5amJcTjeDgLXIjtQLMst",
#         "name" : "SAYGRACE",
#         "type" : "artist",
#         "uri" : "spotify:artist:6y5amJcTjeDgLXIjtQLMst"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#         },
#         "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#         "id" : "45dkTj5sMRSjrmBSBeiHym",
#         "name" : "Tate McRae",
#         "type" : "artist",
#         "uri" : "spotify:artist:45dkTj5sMRSjrmBSBeiHym"
#       }, {
#         "external_urls" : {
#           "spotify" : "https://open.spotify.com/artist/3JDG63cSaK3xgDnB2H55Xp"
#         },
#         "href" : "https://api.spotify.com/v1/artists/3JDG63cSaK3xgDnB2H55Xp",
#         "id" : "3JDG63cSaK3xgDnB2H55Xp",
#         "name" : "Audrey Mika",
#         "type" : "artist",
#         "uri" : "spotify:artist:3JDG63cSaK3xgDnB2H55Xp"
#       } ],
#       "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/album/3TFb8Wpl3qV4Gh9H94XiRZ"
#       },
#       "href" : "https://api.spotify.com/v1/albums/3TFb8Wpl3qV4Gh9H94XiRZ",
#       "id" : "3TFb8Wpl3qV4Gh9H94XiRZ",
#       "images" : [ {
#         "height" : 640,
#         "url" : "https://i.scdn.co/image/ab67616d0000b273d5a76dd9e9d8eef40459caeb",
#         "width" : 640
#       }, {
#         "height" : 300,
#         "url" : "https://i.scdn.co/image/ab67616d00001e02d5a76dd9e9d8eef40459caeb",
#         "width" : 300
#       }, {
#         "height" : 64,
#         "url" : "https://i.scdn.co/image/ab67616d00004851d5a76dd9e9d8eef40459caeb",
#         "width" : 64
#       } ],
#       "name" : "Boys Ain't Shit (feat. Tate McRae & Audrey Mika)",
#       "release_date" : "2020-04-03",
#       "release_date_precision" : "day",
#       "total_tracks" : 1,
#       "type" : "album",
#       "uri" : "spotify:album:3TFb8Wpl3qV4Gh9H94XiRZ"
#     },
#     "artists" : [ {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/6y5amJcTjeDgLXIjtQLMst"
#       },
#       "href" : "https://api.spotify.com/v1/artists/6y5amJcTjeDgLXIjtQLMst",
#       "id" : "6y5amJcTjeDgLXIjtQLMst",
#       "name" : "SAYGRACE",
#       "type" : "artist",
#       "uri" : "spotify:artist:6y5amJcTjeDgLXIjtQLMst"
#     }, {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/45dkTj5sMRSjrmBSBeiHym"
#       },
#       "href" : "https://api.spotify.com/v1/artists/45dkTj5sMRSjrmBSBeiHym",
#       "id" : "45dkTj5sMRSjrmBSBeiHym",
#       "name" : "Tate McRae",
#       "type" : "artist",
#       "uri" : "spotify:artist:45dkTj5sMRSjrmBSBeiHym"
#     }, {
#       "external_urls" : {
#         "spotify" : "https://open.spotify.com/artist/3JDG63cSaK3xgDnB2H55Xp"
#       },
#       "href" : "https://api.spotify.com/v1/artists/3JDG63cSaK3xgDnB2H55Xp",
#       "id" : "3JDG63cSaK3xgDnB2H55Xp",
#       "name" : "Audrey Mika",
#       "type" : "artist",
#       "uri" : "spotify:artist:3JDG63cSaK3xgDnB2H55Xp"
#     } ],
#     "available_markets" : [ "AD", "AE", "AR", "AT", "AU", "BE", "BG", "BH", "BO", "BR", "CA", "CH", "CL", "CO", "CR", "CY", "CZ", "DE", "DK", "DO", "DZ", "EC", "EE", "EG", "ES", "FI", "FR", "GB", "GR", "GT", "HK", "HN", "HU", "ID", "IE", "IL", "IN", "IS", "IT", "JO", "JP", "KW", "LB", "LI", "LT", "LU", "LV", "MA", "MC", "MT", "MX", "MY", "NI", "NL", "NO", "NZ", "OM", "PA", "PE", "PH", "PL", "PS", "PT", "PY", "QA", "RO", "SA", "SE", "SG", "SK", "SV", "TH", "TN", "TR", "TW", "US", "UY", "VN", "ZA" ],
#     "disc_number" : 1,
#     "duration_ms" : 186409,
#     "explicit" : true,
#     "external_ids" : {
#       "isrc" : "USRC12000912"
#     },
#     "external_urls" : {
#       "spotify" : "https://open.spotify.com/track/7tMEUrMaMzE0YptCGfsXzt"
#     },
#     "href" : "https://api.spotify.com/v1/tracks/7tMEUrMaMzE0YptCGfsXzt",
#     "id" : "7tMEUrMaMzE0YptCGfsXzt",
#     "is_local" : false,
#     "name" : "Boys Ain't Shit (feat. Tate McRae & Audrey Mika)",
#     "popularity" : 69,
#     "preview_url" : "https://p.scdn.co/mp3-preview/b74603ef4586a031158bd0a3692d09df4ccc087c?cid=e738e985fed449e8846df5ee72139b87",
#     "track_number" : 1,
#     "type" : "track",
#     "uri" : "spotify:track:7tMEUrMaMzE0YptCGfsXzt"
#   } ],
#   "total" : 50,
#   "limit" : 20,
#   "offset" : 0,
#   "previous" : null,
#   "href" : "https://api.spotify.com/v1/me/top/tracks",
#   "next" : "https://api.spotify.com/v1/me/top/tracks?limit=20&offset=20"
# }
