# %%
import base64
import requests
import datetime
from urllib.parse import urlencode

# %%
client_id = 'e738e985fed449e8846df5ee72139b87'
client_secret = '74b5a5f1c5b54fd6bde889ed6615d708'

# %%
class SpotifyAPI(object):
    access_token = None
    access_token_expires = datetime.datetime.now()
    access_token_did_expire = True
    client_id = None
    client_secret = None
    token_url = 'https://accounts.spotify.com/api/token'
    
    def __init__(self, client_id, client_secret):
        self.client_id = client_id
        self.client_secret = client_secret
    
    def get_token_headers(self):
        client_creds = f"{self.client_id}:{self.client_secret}"
        client_creds_b64 = base64.b64encode(client_creds.encode())
        return {"Authorization": f"Basic {client_creds_b64.decode()}"}
    
    def get_token_data(self):
        return {"grant_type": "client_credentials"}
    
    def perform_auth(self):
        token_url = self.token_url
        token_data = self.get_token_data()
        token_headers = self.get_token_headers()
        r = requests.post(token_url, data=token_data, headers=token_headers)
        if r.status_code not in range(200,299):
            return False
        token_response_data = r.json()
        now = datetime.datetime.now()
        access_token = token_response_data['access_token']
        expires_in = token_response_data['expires_in']
        expires = now + datetime.timedelta(seconds=expires_in)
        self.access_token = access_token
        self.access_token_expires = expires
        self.access_token_did_expire = expires < now
        return True
    
    def get_access_token(self):
        auth_done = self.perform_auth()
        token = self.access_token
        expires = self.access_token_expires
        now = datetime.datetime.now()
        if expires < now:
            self.perform_auth()
            return self.get_access_token()
        elif token == None:
            self.perform_auth()
            return self.get_access_token()
        return token
    
    def get_resource_header(self):
        access_token = self.get_access_token()
        headers = {
            "Authorization": f"Bearer {access_token}"
        }
        return headers
    
    def get_resource(self, _id, resource_type="albums"):
        endpoint = f"https://api.spotify.com/v1/{resource_type}/{_id}"
        headers = self.get_resource_header()
        r = requests.get(endpoint, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()
    
    def get_album(self, _id):
        return self.get_resource(_id, resource_type='albums')
    
    def get_artist(self, _id):
        return self.get_resource(_id, resource_type='artists')
    
    def search(self, query, search_type='artist'):
        headers = self.get_resource_header()
        url = "https://api.spotify.com/v1/search"
        data = urlencode({
            "q": "Blank Space", 
            "type": "track"
        })

        lookup_url = f"{url}?{data}"
        r = requests.get(lookup_url, headers=headers)
        if r.status_code not in range(200,299):
            return {}
        return r.json()

# %%
client = SpotifyAPI(client_id, client_secret)

# %%
client.search("Time", search_type="Track")
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Blank+Space&type=track&offset=0&limit=20',
#   'items': [{'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#      'href': 'https://api.spotify.com/v1/albums/2QJmrSgbdM35R67eoGQo4j',
#      'id': '2QJmrSgbdM35R67eoGQo4j',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273c79b600289a80aaef74d155d',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02c79b600289a80aaef74d155d',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851c79b600289a80aaef74d155d',
#        'width': 64}],
#      'name': '1989',
#      'release_date': '2014-10-27',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:2QJmrSgbdM35R67eoGQo4j'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 231826,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCJY1431309'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1p80LdxRV74UKvL8gnD7ky'},
#     'href': 'https://api.spotify.com/v1/tracks/1p80LdxRV74UKvL8gnD7ky',
#     'id': '1p80LdxRV74UKvL8gnD7ky',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 71,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1p80LdxRV74UKvL8gnD7ky'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Uobr6LgQpBbk6k4QGAb3V'},
#        'href': 'https://api.spotify.com/v1/artists/3Uobr6LgQpBbk6k4QGAb3V',
#        'id': '3Uobr6LgQpBbk6k4QGAb3V',
#        'name': 'I Prevail',
#        'type': 'artist',
#        'uri': 'spotify:artist:3Uobr6LgQpBbk6k4QGAb3V'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6bywSFiasl6HpfQLDvh0az'},
#      'href': 'https://api.spotify.com/v1/albums/6bywSFiasl6HpfQLDvh0az',
#      'id': '6bywSFiasl6HpfQLDvh0az',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2737294c3d8698783718955a286',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e027294c3d8698783718955a286',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048517294c3d8698783718955a286',
#        'width': 64}],
#      'name': 'Heart Vs. Mind',
#      'release_date': '2014-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 8,
#      'type': 'album',
#      'uri': 'spotify:album:6bywSFiasl6HpfQLDvh0az'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3Uobr6LgQpBbk6k4QGAb3V'},
#       'href': 'https://api.spotify.com/v1/artists/3Uobr6LgQpBbk6k4QGAb3V',
#       'id': '3Uobr6LgQpBbk6k4QGAb3V',
#       'name': 'I Prevail',
#       'type': 'artist',
#       'uri': 'spotify:artist:3Uobr6LgQpBbk6k4QGAb3V'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 240927,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACC1437531'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2ZiJidFdQ30nVJEP4u44l3'},
#     'href': 'https://api.spotify.com/v1/tracks/2ZiJidFdQ30nVJEP4u44l3',
#     'id': '2ZiJidFdQ30nVJEP4u44l3',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 64,
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:2ZiJidFdQ30nVJEP4u44l3'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#        'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#        'id': '53XhwfbYqKCa1cC15pYq2q',
#        'name': 'Imagine Dragons',
#        'type': 'artist',
#        'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0XMkrjoxpwaGgb6MYgv2gA'},
#      'href': 'https://api.spotify.com/v1/albums/0XMkrjoxpwaGgb6MYgv2gA',
#      'id': '0XMkrjoxpwaGgb6MYgv2gA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273d934d10b3cdbe79852c87f69',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02d934d10b3cdbe79852c87f69',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851d934d10b3cdbe79852c87f69',
#        'width': 64}],
#      'name': 'Imagine Dragons (Spotify Sessions)',
#      'release_date': '2015-04-20',
#      'release_date_precision': 'day',
#      'total_tracks': 4,
#      'type': 'album',
#      'uri': 'spotify:album:0XMkrjoxpwaGgb6MYgv2gA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/53XhwfbYqKCa1cC15pYq2q'},
#       'href': 'https://api.spotify.com/v1/artists/53XhwfbYqKCa1cC15pYq2q',
#       'id': '53XhwfbYqKCa1cC15pYq2q',
#       'name': 'Imagine Dragons',
#       'type': 'artist',
#       'uri': 'spotify:artist:53XhwfbYqKCa1cC15pYq2q'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 303433,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUM71504446'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3Dbgo1HE3DErIBNDIO4Hyd'},
#     'href': 'https://api.spotify.com/v1/tracks/3Dbgo1HE3DErIBNDIO4Hyd',
#     'id': '3Dbgo1HE3DErIBNDIO4Hyd',
#     'is_local': False,
#     'name': 'Blank Space/Stand By Me - Live From Spotify London',
#     'popularity': 66,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:3Dbgo1HE3DErIBNDIO4Hyd'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wBOZ9D65AcqUlfKUqsQ7R'},
#        'href': 'https://api.spotify.com/v1/artists/6wBOZ9D65AcqUlfKUqsQ7R',
#        'id': '6wBOZ9D65AcqUlfKUqsQ7R',
#        'name': 'Brooklyn Duo',
#        'type': 'artist',
#        'uri': 'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7hBwTnRSuuOisqubNG4lwv'},
#      'href': 'https://api.spotify.com/v1/albums/7hBwTnRSuuOisqubNG4lwv',
#      'id': '7hBwTnRSuuOisqubNG4lwv',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732bb94c4171b3a43f2244e7c3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022bb94c4171b3a43f2244e7c3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512bb94c4171b3a43f2244e7c3',
#        'width': 64}],
#      'name': 'Brooklyn Sessions',
#      'release_date': '2014-11-27',
#      'release_date_precision': 'day',
#      'total_tracks': 10,
#      'type': 'album',
#      'uri': 'spotify:album:7hBwTnRSuuOisqubNG4lwv'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6wBOZ9D65AcqUlfKUqsQ7R'},
#       'href': 'https://api.spotify.com/v1/artists/6wBOZ9D65AcqUlfKUqsQ7R',
#       'id': '6wBOZ9D65AcqUlfKUqsQ7R',
#       'name': 'Brooklyn Duo',
#       'type': 'artist',
#       'uri': 'spotify:artist:6wBOZ9D65AcqUlfKUqsQ7R'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 155495,
#     'explicit': False,
#     'external_ids': {'isrc': 'TCACC1414069'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2mMarfkPpZPPKV5AUGdz58'},
#     'href': 'https://api.spotify.com/v1/tracks/2mMarfkPpZPPKV5AUGdz58',
#     'id': '2mMarfkPpZPPKV5AUGdz58',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d6ff7cbc03f7c10c9b6b9a31c9b5ac82fadaa172?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:2mMarfkPpZPPKV5AUGdz58'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qc41rNTtdLK0tV3mJn2Pm'},
#        'href': 'https://api.spotify.com/v1/artists/2qc41rNTtdLK0tV3mJn2Pm',
#        'id': '2qc41rNTtdLK0tV3mJn2Pm',
#        'name': 'Ryan Adams',
#        'type': 'artist',
#        'uri': 'spotify:artist:2qc41rNTtdLK0tV3mJn2Pm'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0MVK1j7wrUkBZ09ZuMURJA'},
#      'href': 'https://api.spotify.com/v1/albums/0MVK1j7wrUkBZ09ZuMURJA',
#      'id': '0MVK1j7wrUkBZ09ZuMURJA',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273536e8d127e6e6613971ddcde',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02536e8d127e6e6613971ddcde',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851536e8d127e6e6613971ddcde',
#        'width': 64}],
#      'name': '1989',
#      'release_date': '2015-09-21',
#      'release_date_precision': 'day',
#      'total_tracks': 13,
#      'type': 'album',
#      'uri': 'spotify:album:0MVK1j7wrUkBZ09ZuMURJA'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2qc41rNTtdLK0tV3mJn2Pm'},
#       'href': 'https://api.spotify.com/v1/artists/2qc41rNTtdLK0tV3mJn2Pm',
#       'id': '2qc41rNTtdLK0tV3mJn2Pm',
#       'name': 'Ryan Adams',
#       'type': 'artist',
#       'uri': 'spotify:artist:2qc41rNTtdLK0tV3mJn2Pm'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 201693,
#     'explicit': False,
#     'external_ids': {'isrc': 'USUG11501142'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7363P58oxh8jr5NEv7086t'},
#     'href': 'https://api.spotify.com/v1/tracks/7363P58oxh8jr5NEv7086t',
#     'id': '7363P58oxh8jr5NEv7086t',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 40,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:7363P58oxh8jr5NEv7086t'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MVrehTlNNnn06iUlj4axN'},
#        'href': 'https://api.spotify.com/v1/artists/3MVrehTlNNnn06iUlj4axN',
#        'id': '3MVrehTlNNnn06iUlj4axN',
#        'name': 'Daniel Jang',
#        'type': 'artist',
#        'uri': 'spotify:artist:3MVrehTlNNnn06iUlj4axN'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0oq0NYk7GZ0BfEPYXO18CE'},
#      'href': 'https://api.spotify.com/v1/albums/0oq0NYk7GZ0BfEPYXO18CE',
#      'id': '0oq0NYk7GZ0BfEPYXO18CE',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2732a26f4e34ff7740688e372b9',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e022a26f4e34ff7740688e372b9',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048512a26f4e34ff7740688e372b9',
#        'width': 64}],
#      'name': 'Violin Covers Pt. III',
#      'release_date': '2016-01-22',
#      'release_date_precision': 'day',
#      'total_tracks': 11,
#      'type': 'album',
#      'uri': 'spotify:album:0oq0NYk7GZ0BfEPYXO18CE'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3MVrehTlNNnn06iUlj4axN'},
#       'href': 'https://api.spotify.com/v1/artists/3MVrehTlNNnn06iUlj4axN',
#       'id': '3MVrehTlNNnn06iUlj4axN',
#       'name': 'Daniel Jang',
#       'type': 'artist',
#       'uri': 'spotify:artist:3MVrehTlNNnn06iUlj4axN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235013,
#     'explicit': False,
#     'external_ids': {'isrc': 'USE831533647'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4k5uVjbGuxaLCv5B0ukVJT'},
#     'href': 'https://api.spotify.com/v1/tracks/4k5uVjbGuxaLCv5B0ukVJT',
#     'id': '4k5uVjbGuxaLCv5B0ukVJT',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 43,
#     'preview_url': 'https://p.scdn.co/mp3-preview/f77f2d1dc92d768e089df444f4fa631ae30bc018?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:4k5uVjbGuxaLCv5B0ukVJT'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00YTqRClk82aMchQQpYMd5'},
#        'href': 'https://api.spotify.com/v1/artists/00YTqRClk82aMchQQpYMd5',
#        'id': '00YTqRClk82aMchQQpYMd5',
#        'name': 'Our Last Night',
#        'type': 'artist',
#        'uri': 'spotify:artist:00YTqRClk82aMchQQpYMd5'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6vEkZHRxAKqXumPoASL0PX'},
#      'href': 'https://api.spotify.com/v1/albums/6vEkZHRxAKqXumPoASL0PX',
#      'id': '6vEkZHRxAKqXumPoASL0PX',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739126e12a8d6d99ff6cc41719',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029126e12a8d6d99ff6cc41719',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519126e12a8d6d99ff6cc41719',
#        'width': 64}],
#      'name': 'Blank Space (Rock)',
#      'release_date': '2015-01-20',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:6vEkZHRxAKqXumPoASL0PX'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/00YTqRClk82aMchQQpYMd5'},
#       'href': 'https://api.spotify.com/v1/artists/00YTqRClk82aMchQQpYMd5',
#       'id': '00YTqRClk82aMchQQpYMd5',
#       'name': 'Our Last Night',
#       'type': 'artist',
#       'uri': 'spotify:artist:00YTqRClk82aMchQQpYMd5'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 233794,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDMT1500023'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4qxnqB38Ilk0atKmbQ8UB4'},
#     'href': 'https://api.spotify.com/v1/tracks/4qxnqB38Ilk0atKmbQ8UB4',
#     'id': '4qxnqB38Ilk0atKmbQ8UB4',
#     'is_local': False,
#     'name': 'Blank Space - Rock',
#     'popularity': 46,
#     'preview_url': 'https://p.scdn.co/mp3-preview/6d57d9b71304e48f647b1760a850bb223bfa8be8?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:4qxnqB38Ilk0atKmbQ8UB4'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#        'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#        'id': '06HL4z0CvFAxyc27GXpf02',
#        'name': 'Taylor Swift',
#        'type': 'artist',
#        'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/34OkZVpuzBa9y40DCy0LPR'},
#      'href': 'https://api.spotify.com/v1/albums/34OkZVpuzBa9y40DCy0LPR',
#      'id': '34OkZVpuzBa9y40DCy0LPR',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273332d85510aba3eb28312cfb2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02332d85510aba3eb28312cfb2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851332d85510aba3eb28312cfb2',
#        'width': 64}],
#      'name': '1989 (Deluxe Edition)',
#      'release_date': '2014-10-27',
#      'release_date_precision': 'day',
#      'total_tracks': 19,
#      'type': 'album',
#      'uri': 'spotify:album:34OkZVpuzBa9y40DCy0LPR'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 131186,
#     'explicit': False,
#     'external_ids': {'isrc': 'USCJY1431481'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0yisH8r0f3Mkq34kjzUlCV'},
#     'href': 'https://api.spotify.com/v1/tracks/0yisH8r0f3Mkq34kjzUlCV',
#     'id': '0yisH8r0f3Mkq34kjzUlCV',
#     'is_local': False,
#     'name': 'Blank Space - Voice Memo',
#     'popularity': 39,
#     'preview_url': None,
#     'track_number': 19,
#     'type': 'track',
#     'uri': 'spotify:track:0yisH8r0f3Mkq34kjzUlCV'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Vvvx45Apu6dQqwuZQxtgW'},
#        'href': 'https://api.spotify.com/v1/artists/1Vvvx45Apu6dQqwuZQxtgW',
#        'id': '1Vvvx45Apu6dQqwuZQxtgW',
#        'name': 'Kidz Bop Kids',
#        'type': 'artist',
#        'uri': 'spotify:artist:1Vvvx45Apu6dQqwuZQxtgW'}],
#      'available_markets': ['CA', 'US'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/2Vh73FD6YV5afi2SVJ8qkB'},
#      'href': 'https://api.spotify.com/v1/albums/2Vh73FD6YV5afi2SVJ8qkB',
#      'id': '2Vh73FD6YV5afi2SVJ8qkB',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2739f68596675cb2e9054bded96',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e029f68596675cb2e9054bded96',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048519f68596675cb2e9054bded96',
#        'width': 64}],
#      'name': 'Kidz Bop 28',
#      'release_date': '2015-03-24',
#      'release_date_precision': 'day',
#      'total_tracks': 14,
#      'type': 'album',
#      'uri': 'spotify:album:2Vh73FD6YV5afi2SVJ8qkB'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1Vvvx45Apu6dQqwuZQxtgW'},
#       'href': 'https://api.spotify.com/v1/artists/1Vvvx45Apu6dQqwuZQxtgW',
#       'id': '1Vvvx45Apu6dQqwuZQxtgW',
#       'name': 'Kidz Bop Kids',
#       'type': 'artist',
#       'uri': 'spotify:artist:1Vvvx45Apu6dQqwuZQxtgW'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 172293,
#     'explicit': False,
#     'external_ids': {'isrc': 'USRZO1537402'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/2cbk1iymUvgSSyad62RRSh'},
#     'href': 'https://api.spotify.com/v1/tracks/2cbk1iymUvgSSyad62RRSh',
#     'id': '2cbk1iymUvgSSyad62RRSh',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 33,
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:2cbk1iymUvgSSyad62RRSh'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZpgFvvFmKWHTfyJUFeSDH'},
#        'href': 'https://api.spotify.com/v1/artists/5ZpgFvvFmKWHTfyJUFeSDH',
#        'id': '5ZpgFvvFmKWHTfyJUFeSDH',
#        'name': 'Larstigst',
#        'type': 'artist',
#        'uri': 'spotify:artist:5ZpgFvvFmKWHTfyJUFeSDH'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/7Epxvb6zEcs3pkp3DUfh1t'},
#      'href': 'https://api.spotify.com/v1/albums/7Epxvb6zEcs3pkp3DUfh1t',
#      'id': '7Epxvb6zEcs3pkp3DUfh1t',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273686a51210de9a3bb703b350f',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02686a51210de9a3bb703b350f',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851686a51210de9a3bb703b350f',
#        'width': 64}],
#      'name': 'Life Knowledge',
#      'release_date': '2020-09-25',
#      'release_date_precision': 'day',
#      'total_tracks': 6,
#      'type': 'album',
#      'uri': 'spotify:album:7Epxvb6zEcs3pkp3DUfh1t'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5ZpgFvvFmKWHTfyJUFeSDH'},
#       'href': 'https://api.spotify.com/v1/artists/5ZpgFvvFmKWHTfyJUFeSDH',
#       'id': '5ZpgFvvFmKWHTfyJUFeSDH',
#       'name': 'Larstigst',
#       'type': 'artist',
#       'uri': 'spotify:artist:5ZpgFvvFmKWHTfyJUFeSDH'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 145975,
#     'explicit': False,
#     'external_ids': {'isrc': 'QZK6F2030353'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Q5JAu7IdGQj9izO9Jgv3D'},
#     'href': 'https://api.spotify.com/v1/tracks/1Q5JAu7IdGQj9izO9Jgv3D',
#     'id': '1Q5JAu7IdGQj9izO9Jgv3D',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/63ce9fbc007e52fddfd38fd60352db8d0b741628?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1Q5JAu7IdGQj9izO9Jgv3D'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hc9oDGvStNGmnj44m8sHg'},
#        'href': 'https://api.spotify.com/v1/artists/5Hc9oDGvStNGmnj44m8sHg',
#        'id': '5Hc9oDGvStNGmnj44m8sHg',
#        'name': 'Tyler Ward',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Hc9oDGvStNGmnj44m8sHg'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3SH97wy4KAABVkVBItE8j1'},
#      'href': 'https://api.spotify.com/v1/albums/3SH97wy4KAABVkVBItE8j1',
#      'id': '3SH97wy4KAABVkVBItE8j1',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273bcda9dcf4e728c0240495520',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02bcda9dcf4e728c0240495520',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851bcda9dcf4e728c0240495520',
#        'width': 64}],
#      'name': "Cookin' Covers",
#      'release_date': '2015-04-13',
#      'release_date_precision': 'day',
#      'total_tracks': 7,
#      'type': 'album',
#      'uri': 'spotify:album:3SH97wy4KAABVkVBItE8j1'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Hc9oDGvStNGmnj44m8sHg'},
#       'href': 'https://api.spotify.com/v1/artists/5Hc9oDGvStNGmnj44m8sHg',
#       'id': '5Hc9oDGvStNGmnj44m8sHg',
#       'name': 'Tyler Ward',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Hc9oDGvStNGmnj44m8sHg'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 190539,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDMT1400453'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7bF9y8lripis7LqY8wbZkO'},
#     'href': 'https://api.spotify.com/v1/tracks/7bF9y8lripis7LqY8wbZkO',
#     'id': '7bF9y8lripis7LqY8wbZkO',
#     'is_local': False,
#     'name': 'Blank Space - Acoustic',
#     'popularity': 42,
#     'preview_url': 'https://p.scdn.co/mp3-preview/b06075cb149f77617e3f23de5cc2c6583b29ed74?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:7bF9y8lripis7LqY8wbZkO'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07FfkbljNIdl45Ijlh1aXS'},
#        'href': 'https://api.spotify.com/v1/artists/07FfkbljNIdl45Ijlh1aXS',
#        'id': '07FfkbljNIdl45Ijlh1aXS',
#        'name': 'RHODES',
#        'type': 'artist',
#        'uri': 'spotify:artist:07FfkbljNIdl45Ijlh1aXS'}],
#      'available_markets': ['AR',
#       'BO',
#       'BR',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'GB',
#       'GT',
#       'HN',
#       'IE',
#       'JP',
#       'MX',
#       'NI',
#       'PA',
#       'PE',
#       'PY',
#       'SV',
#       'US',
#       'UY',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3CV2SCBs7wAUoQbmnjQbwa'},
#      'href': 'https://api.spotify.com/v1/albums/3CV2SCBs7wAUoQbmnjQbwa',
#      'id': '3CV2SCBs7wAUoQbmnjQbwa',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27342d939e73d1799ade999096e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0242d939e73d1799ade999096e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485142d939e73d1799ade999096e',
#        'width': 64}],
#      'name': 'Wishes (Deluxe Version)',
#      'release_date': '2015-09-18',
#      'release_date_precision': 'day',
#      'total_tracks': 18,
#      'type': 'album',
#      'uri': 'spotify:album:3CV2SCBs7wAUoQbmnjQbwa'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/07FfkbljNIdl45Ijlh1aXS'},
#       'href': 'https://api.spotify.com/v1/artists/07FfkbljNIdl45Ijlh1aXS',
#       'id': '07FfkbljNIdl45Ijlh1aXS',
#       'name': 'RHODES',
#       'type': 'artist',
#       'uri': 'spotify:artist:07FfkbljNIdl45Ijlh1aXS'}],
#     'available_markets': ['AR',
#      'BO',
#      'BR',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'DO',
#      'EC',
#      'GB',
#      'GT',
#      'HN',
#      'IE',
#      'JP',
#      'MX',
#      'NI',
#      'PA',
#      'PE',
#      'PY',
#      'SV',
#      'US',
#      'UY',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 247440,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBCEN1500611'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/112HnbIN8JpmeNDDOgTSv0'},
#     'href': 'https://api.spotify.com/v1/tracks/112HnbIN8JpmeNDDOgTSv0',
#     'id': '112HnbIN8JpmeNDDOgTSv0',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 36,
#     'preview_url': 'https://p.scdn.co/mp3-preview/34ab5d69f7382e7818a8b04b22bb21f3e9dde0cf?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 16,
#     'type': 'track',
#     'uri': 'spotify:track:112HnbIN8JpmeNDDOgTSv0'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HYNPEO2NNBONQkp3Mvwvc'},
#        'href': 'https://api.spotify.com/v1/artists/5HYNPEO2NNBONQkp3Mvwvc',
#        'id': '5HYNPEO2NNBONQkp3Mvwvc',
#        'name': "Scott Bradlee's Postmodern Jukebox",
#        'type': 'artist',
#        'uri': 'spotify:artist:5HYNPEO2NNBONQkp3Mvwvc'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1jRyMHSkbnP8GwptMnh66z'},
#      'href': 'https://api.spotify.com/v1/albums/1jRyMHSkbnP8GwptMnh66z',
#      'id': '1jRyMHSkbnP8GwptMnh66z',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273cbd2dfb4d97eab0b6d55d3a3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02cbd2dfb4d97eab0b6d55d3a3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851cbd2dfb4d97eab0b6d55d3a3',
#        'width': 64}],
#      'name': 'Selfies on Kodachrome',
#      'release_date': '2015-01-13',
#      'release_date_precision': 'day',
#      'total_tracks': 15,
#      'type': 'album',
#      'uri': 'spotify:album:1jRyMHSkbnP8GwptMnh66z'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5HYNPEO2NNBONQkp3Mvwvc'},
#       'href': 'https://api.spotify.com/v1/artists/5HYNPEO2NNBONQkp3Mvwvc',
#       'id': '5HYNPEO2NNBONQkp3Mvwvc',
#       'name': "Scott Bradlee's Postmodern Jukebox",
#       'type': 'artist',
#       'uri': 'spotify:artist:5HYNPEO2NNBONQkp3Mvwvc'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/6neK0Nwb4rkGnehK4zL8iN'},
#       'href': 'https://api.spotify.com/v1/artists/6neK0Nwb4rkGnehK4zL8iN',
#       'id': '6neK0Nwb4rkGnehK4zL8iN',
#       'name': 'Ariana Savalas',
#       'type': 'artist',
#       'uri': 'spotify:artist:6neK0Nwb4rkGnehK4zL8iN'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 274250,
#     'explicit': False,
#     'external_ids': {'isrc': 'GBDMT1400526'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5NU6A2GoTK67ydAcxDkrKm'},
#     'href': 'https://api.spotify.com/v1/tracks/5NU6A2GoTK67ydAcxDkrKm',
#     'id': '5NU6A2GoTK67ydAcxDkrKm',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 39,
#     'preview_url': 'https://p.scdn.co/mp3-preview/073357b9839ae917dcb12f02242b192387b34754?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5NU6A2GoTK67ydAcxDkrKm'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SiJyDbdaigXe99RB6crls'},
#        'href': 'https://api.spotify.com/v1/artists/1SiJyDbdaigXe99RB6crls',
#        'id': '1SiJyDbdaigXe99RB6crls',
#        'name': 'LA Nightcore',
#        'type': 'artist',
#        'uri': 'spotify:artist:1SiJyDbdaigXe99RB6crls'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0iM1FZt2GDJ1R9XwuzRwCS'},
#      'href': 'https://api.spotify.com/v1/albums/0iM1FZt2GDJ1R9XwuzRwCS',
#      'id': '0iM1FZt2GDJ1R9XwuzRwCS',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731a61b1e395469b2e62bfe43e',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021a61b1e395469b2e62bfe43e',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511a61b1e395469b2e62bfe43e',
#        'width': 64}],
#      'name': 'Blank Space (Nightcore Remix)',
#      'release_date': '2015-11-19',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:0iM1FZt2GDJ1R9XwuzRwCS'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1SiJyDbdaigXe99RB6crls'},
#       'href': 'https://api.spotify.com/v1/artists/1SiJyDbdaigXe99RB6crls',
# ...
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/18CFSHD958HJKPPTkj7UCi'},
#      'href': 'https://api.spotify.com/v1/albums/18CFSHD958HJKPPTkj7UCi',
#      'id': '18CFSHD958HJKPPTkj7UCi',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273fce7cda633a46943a44818c3',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02fce7cda633a46943a44818c3',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851fce7cda633a46943a44818c3',
#        'width': 64}],
#      'name': 'Blank Space',
#      'release_date': '2014-12-16',
#      'release_date_precision': 'day',
#      'total_tracks': 1,
#      'type': 'album',
#      'uri': 'spotify:album:18CFSHD958HJKPPTkj7UCi'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0AzuWkctYHGiN8uVae3LOw'},
#       'href': 'https://api.spotify.com/v1/artists/0AzuWkctYHGiN8uVae3LOw',
#       'id': '0AzuWkctYHGiN8uVae3LOw',
#       'name': 'Far From Over',
#       'type': 'artist',
#       'uri': 'spotify:artist:0AzuWkctYHGiN8uVae3LOw'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235000,
#     'explicit': False,
#     'external_ids': {'isrc': 'usx9p1438688'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6a93MtcBvFSbNGnqS9lTTN'},
#     'href': 'https://api.spotify.com/v1/tracks/6a93MtcBvFSbNGnqS9lTTN',
#     'id': '6a93MtcBvFSbNGnqS9lTTN',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 32,
#     'preview_url': 'https://p.scdn.co/mp3-preview/5bd7e70b9244330652980cfca684a6ca351a71f1?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6a93MtcBvFSbNGnqS9lTTN'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#        'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#        'id': '6MERXsiRbur2oJZFgYRDKz',
#        'name': 'Vitamin String Quartet',
#        'type': 'artist',
#        'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/55GWGl6XdbV5M9OfhiGtMN'},
#      'href': 'https://api.spotify.com/v1/albums/55GWGl6XdbV5M9OfhiGtMN',
#      'id': '55GWGl6XdbV5M9OfhiGtMN',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731c2a0c0ce5441bca49e3dbc1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021c2a0c0ce5441bca49e3dbc1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511c2a0c0ce5441bca49e3dbc1',
#        'width': 64}],
#      'name': 'VSQ Performs the Hits of 2014, Vol. 3',
#      'release_date': '2015-01-20',
#      'release_date_precision': 'day',
#      'total_tracks': 9,
#      'type': 'album',
#      'uri': 'spotify:album:55GWGl6XdbV5M9OfhiGtMN'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6MERXsiRbur2oJZFgYRDKz'},
#       'href': 'https://api.spotify.com/v1/artists/6MERXsiRbur2oJZFgYRDKz',
#       'id': '6MERXsiRbur2oJZFgYRDKz',
#       'name': 'Vitamin String Quartet',
#       'type': 'artist',
#       'uri': 'spotify:artist:6MERXsiRbur2oJZFgYRDKz'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 235626,
#     'explicit': False,
#     'external_ids': {'isrc': 'USEWC1589235'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3jIIsSXGcrzWAYfKYgv0Dk'},
#     'href': 'https://api.spotify.com/v1/tracks/3jIIsSXGcrzWAYfKYgv0Dk',
#     'id': '3jIIsSXGcrzWAYfKYgv0Dk',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 29,
#     'preview_url': 'https://p.scdn.co/mp3-preview/3a5a8a0e614431bd4236c8297563175ad3bf0763?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:3jIIsSXGcrzWAYfKYgv0Dk'},
#    {'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Sng1k7qku7n6WAJsL1euv'},
#        'href': 'https://api.spotify.com/v1/artists/5Sng1k7qku7n6WAJsL1euv',
#        'id': '5Sng1k7qku7n6WAJsL1euv',
#        'name': 'Nothing But Treble',
#        'type': 'artist',
#        'uri': 'spotify:artist:5Sng1k7qku7n6WAJsL1euv'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/0BXqQ7Ef3Bydr6VOYkPL7h'},
#      'href': 'https://api.spotify.com/v1/albums/0BXqQ7Ef3Bydr6VOYkPL7h',
#      'id': '0BXqQ7Ef3Bydr6VOYkPL7h',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b27369b5bcff30c9350e85a5c498',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e0269b5bcff30c9350e85a5c498',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d0000485169b5bcff30c9350e85a5c498',
#        'width': 64}],
#      'name': 'This Time',
#      'release_date': '2015-10-15',
#      'release_date_precision': 'day',
#      'total_tracks': 3,
#      'type': 'album',
#      'uri': 'spotify:album:0BXqQ7Ef3Bydr6VOYkPL7h'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5Sng1k7qku7n6WAJsL1euv'},
#       'href': 'https://api.spotify.com/v1/artists/5Sng1k7qku7n6WAJsL1euv',
#       'id': '5Sng1k7qku7n6WAJsL1euv',
#       'name': 'Nothing But Treble',
#       'type': 'artist',
#       'uri': 'spotify:artist:5Sng1k7qku7n6WAJsL1euv'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 175333,
#     'explicit': False,
#     'external_ids': {'isrc': 'USE831510858'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1Qo2sTjyk9pp0rOGKcGvfr'},
#     'href': 'https://api.spotify.com/v1/tracks/1Qo2sTjyk9pp0rOGKcGvfr',
#     'id': '1Qo2sTjyk9pp0rOGKcGvfr',
#     'is_local': False,
#     'name': 'Blank Space/Style',
#     'popularity': 33,
#     'preview_url': 'https://p.scdn.co/mp3-preview/40feda0caa2d6959c9f24f3081a5dd4a1d2f13d2?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1Qo2sTjyk9pp0rOGKcGvfr'},
#    {'album': {'album_type': 'album',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'available_markets': ['AD',
#       'AE',
#       'AL',
#       'AR',
#       'AT',
#       'AU',
#       'BA',
#       'BE',
#       'BG',
#       'BH',
#       'BO',
#       'BR',
#       'BY',
#       'CA',
#       'CH',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DE',
#       'DK',
#       'DO',
#       'DZ',
#       'EC',
#       'EE',
#       'EG',
#       'ES',
#       'FI',
#       'FR',
#       'GB',
#       'GR',
#       'GT',
#       'HK',
#       'HN',
#       'HR',
#       'HU',
#       'ID',
#       'IE',
#       'IL',
#       'IN',
#       'IS',
#       'IT',
#       'JO',
#       'JP',
#       'KW',
#       'KZ',
#       'LB',
#       'LI',
#       'LT',
#       'LU',
#       'LV',
#       'MA',
#       'MC',
#       'MD',
#       'ME',
#       'MK',
#       'MT',
#       'MX',
#       'MY',
#       'NI',
#       'NL',
#       'NO',
#       'NZ',
#       'OM',
#       'PA',
#       'PE',
#       'PH',
#       'PL',
#       'PS',
#       'PT',
#       'PY',
#       'QA',
#       'RO',
#       'RS',
#       'RU',
#       'SA',
#       'SE',
#       'SG',
#       'SI',
#       'SK',
#       'SV',
#       'TH',
#       'TN',
#       'TR',
#       'TW',
#       'UA',
#       'US',
#       'UY',
#       'VN',
#       'XK',
#       'ZA'],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3Ep6LsYNqvfKNLzwGeo63Y'},
#      'href': 'https://api.spotify.com/v1/albums/3Ep6LsYNqvfKNLzwGeo63Y',
#      'id': '3Ep6LsYNqvfKNLzwGeo63Y',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2730459746ca2565aac729c0e65',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e020459746ca2565aac729c0e65',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048510459746ca2565aac729c0e65',
#        'width': 64}],
#      'name': 'Make It Pop, Vol. 16',
#      'release_date': '2020-02-05',
#      'release_date_precision': 'day',
#      'total_tracks': 40,
#      'type': 'album',
#      'uri': 'spotify:album:3Ep6LsYNqvfKNLzwGeo63Y'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0zUwpfbpk07QByS5MFfBqB'},
#       'href': 'https://api.spotify.com/v1/artists/0zUwpfbpk07QByS5MFfBqB',
#       'id': '0zUwpfbpk07QByS5MFfBqB',
#       'name': 'Max Hill',
#       'type': 'artist',
#       'uri': 'spotify:artist:0zUwpfbpk07QByS5MFfBqB'}],
#     'available_markets': ['AD',
#      'AE',
#      'AL',
#      'AR',
#      'AT',
#      'AU',
#      'BA',
#      'BE',
#      'BG',
#      'BH',
#      'BO',
#      'BR',
#      'BY',
#      'CA',
#      'CH',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DE',
#      'DK',
#      'DO',
#      'DZ',
#      'EC',
#      'EE',
#      'EG',
#      'ES',
#      'FI',
#      'FR',
#      'GB',
#      'GR',
#      'GT',
#      'HK',
#      'HN',
#      'HR',
#      'HU',
#      'ID',
#      'IE',
#      'IL',
#      'IN',
#      'IS',
#      'IT',
#      'JO',
#      'JP',
#      'KW',
#      'KZ',
#      'LB',
#      'LI',
#      'LT',
#      'LU',
#      'LV',
#      'MA',
#      'MC',
#      'MD',
#      'ME',
#      'MK',
#      'MT',
#      'MX',
#      'MY',
#      'NI',
#      'NL',
#      'NO',
#      'NZ',
#      'OM',
#      'PA',
#      'PE',
#      'PH',
#      'PL',
#      'PS',
#      'PT',
#      'PY',
#      'QA',
#      'RO',
#      'RS',
#      'RU',
#      'SA',
#      'SE',
#      'SG',
#      'SI',
#      'SK',
#      'SV',
#      'TH',
#      'TN',
#      'TR',
#      'TW',
#      'UA',
#      'US',
#      'UY',
#      'VN',
#      'XK',
#      'ZA'],
#     'disc_number': 1,
#     'duration_ms': 231797,
#     'explicit': False,
#     'external_ids': {'isrc': 'AUXN21936779'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6VxwiJWR2gWWtM8bK6rgll'},
#     'href': 'https://api.spotify.com/v1/tracks/6VxwiJWR2gWWtM8bK6rgll',
#     'id': '6VxwiJWR2gWWtM8bK6rgll',
#     'is_local': False,
#     'name': 'Blank Space',
#     'popularity': 35,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e391f7e2ab16348c1d6c3c64e857ab58e4bf0463?cid=e738e985fed449e8846df5ee72139b87',
#     'track_number': 27,
#     'type': 'track',
#     'uri': 'spotify:track:6VxwiJWR2gWWtM8bK6rgll'}],
#   'limit': 20,
#   'next': 'https://api.spotify.com/v1/search?query=Blank+Space&type=track&offset=20&limit=20',
#   'offset': 0,
#   'previous': None,
#   'total': 1629}}

# %%
client.get_artist("06HL4z0CvFAxyc27GXpf02")
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#  'followers': {'href': None, 'total': 33073540},
#  'genres': ['dance pop', 'pop', 'post-teen pop'],
#  'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#  'id': '06HL4z0CvFAxyc27GXpf02',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/a37efbc7fd3f5f5df81b48ce9c6de53820b239c1',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/dc6f0ac18ad5db302e3c8a28b655b6ca7244ef08',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/b1627ca86690d2c5b6cc2fb1039a31014e96a22b',
#    'width': 160}],
#  'name': 'Taylor Swift',
#  'popularity': 96,
#  'type': 'artist',
#  'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}

# %%
client.get_album("2QJmrSgbdM35R67eoGQo4j")
# Out:
# {'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#    'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#    'id': '06HL4z0CvFAxyc27GXpf02',
#    'name': 'Taylor Swift',
#    'type': 'artist',
#    'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#  'available_markets': ['CA', 'US'],
#  'copyrights': [{'text': '© 2014 Big Machine Records, LLC.', 'type': 'C'},
#   {'text': '℗ 2014 Big Machine Records, LLC.', 'type': 'P'}],
#  'external_ids': {'upc': '00843930013555'},
#  'external_urls': {'spotify': 'https://open.spotify.com/album/2QJmrSgbdM35R67eoGQo4j'},
#  'genres': [],
#  'href': 'https://api.spotify.com/v1/albums/2QJmrSgbdM35R67eoGQo4j',
#  'id': '2QJmrSgbdM35R67eoGQo4j',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273c79b600289a80aaef74d155d',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02c79b600289a80aaef74d155d',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851c79b600289a80aaef74d155d',
#    'width': 64}],
#  'label': 'Big Machine Records, LLC',
#  'name': '1989',
#  'popularity': 77,
#  'release_date': '2014-10-27',
#  'release_date_precision': 'day',
#  'total_tracks': 13,
#  'tracks': {'href': 'https://api.spotify.com/v1/albums/2QJmrSgbdM35R67eoGQo4j/tracks?offset=0&limit=50',
#   'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 212600,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/6qnM0XXPZOINWA778uNqQ9'},
#     'href': 'https://api.spotify.com/v1/tracks/6qnM0XXPZOINWA778uNqQ9',
#     'id': '6qnM0XXPZOINWA778uNqQ9',
#     'is_local': False,
#     'name': 'Welcome To New York',
#     'preview_url': None,
#     'track_number': 1,
#     'type': 'track',
#     'uri': 'spotify:track:6qnM0XXPZOINWA778uNqQ9'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 231826,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1p80LdxRV74UKvL8gnD7ky'},
#     'href': 'https://api.spotify.com/v1/tracks/1p80LdxRV74UKvL8gnD7ky',
#     'id': '1p80LdxRV74UKvL8gnD7ky',
#     'is_local': False,
#     'name': 'Blank Space',
#     'preview_url': None,
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1p80LdxRV74UKvL8gnD7ky'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 231000,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4lIxdJw6W3Fg4vUIYCB0S5'},
#     'href': 'https://api.spotify.com/v1/tracks/4lIxdJw6W3Fg4vUIYCB0S5',
#     'id': '4lIxdJw6W3Fg4vUIYCB0S5',
#     'is_local': False,
#     'name': 'Style',
#     'preview_url': None,
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:4lIxdJw6W3Fg4vUIYCB0S5'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 235800,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5OndtwLGA9O6XHFcGm2H7r'},
#     'href': 'https://api.spotify.com/v1/tracks/5OndtwLGA9O6XHFcGm2H7r',
#     'id': '5OndtwLGA9O6XHFcGm2H7r',
#     'is_local': False,
#     'name': 'Out Of The Woods',
#     'preview_url': None,
#     'track_number': 4,
#     'type': 'track',
#     'uri': 'spotify:track:5OndtwLGA9O6XHFcGm2H7r'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 193293,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0dAb8TY433dl3ZfXYCLE19'},
#     'href': 'https://api.spotify.com/v1/tracks/0dAb8TY433dl3ZfXYCLE19',
#     'id': '0dAb8TY433dl3ZfXYCLE19',
#     'is_local': False,
#     'name': 'All You Had To Do Was Stay',
#     'preview_url': None,
#     'track_number': 5,
#     'type': 'track',
#     'uri': 'spotify:track:0dAb8TY433dl3ZfXYCLE19'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 219200,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/5xTtaWoae3wi06K5WfVUUH'},
#     'href': 'https://api.spotify.com/v1/tracks/5xTtaWoae3wi06K5WfVUUH',
#     'id': '5xTtaWoae3wi06K5WfVUUH',
#     'is_local': False,
#     'name': 'Shake It Off',
#     'preview_url': None,
#     'track_number': 6,
#     'type': 'track',
#     'uri': 'spotify:track:5xTtaWoae3wi06K5WfVUUH'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 207440,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3wmN11qXGL0HyPojvEE1D9'},
#     'href': 'https://api.spotify.com/v1/tracks/3wmN11qXGL0HyPojvEE1D9',
#     'id': '3wmN11qXGL0HyPojvEE1D9',
#     'is_local': False,
#     'name': 'I Wish You Would',
#     'preview_url': None,
#     'track_number': 7,
#     'type': 'track',
#     'uri': 'spotify:track:3wmN11qXGL0HyPojvEE1D9'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 211933,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/273dCMFseLcVsoSWx59IoE'},
#     'href': 'https://api.spotify.com/v1/tracks/273dCMFseLcVsoSWx59IoE',
#     'id': '273dCMFseLcVsoSWx59IoE',
#     'is_local': False,
#     'name': 'Bad Blood',
#     'preview_url': None,
#     'track_number': 8,
#     'type': 'track',
#     'uri': 'spotify:track:273dCMFseLcVsoSWx59IoE'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 220440,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/59HjlYCeBsxdI0fcm3zglw'},
#     'href': 'https://api.spotify.com/v1/tracks/59HjlYCeBsxdI0fcm3zglw',
#     'id': '59HjlYCeBsxdI0fcm3zglw',
#     'is_local': False,
#     'name': 'Wildest Dreams',
#     'preview_url': None,
#     'track_number': 9,
#     'type': 'track',
#     'uri': 'spotify:track:59HjlYCeBsxdI0fcm3zglw'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 247533,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/4dYUOfmWna6DFccnz732n8'},
#     'href': 'https://api.spotify.com/v1/tracks/4dYUOfmWna6DFccnz732n8',
#     'id': '4dYUOfmWna6DFccnz732n8',
#     'is_local': False,
#     'name': 'How You Get The Girl',
#     'preview_url': None,
#     'track_number': 10,
#     'type': 'track',
#     'uri': 'spotify:track:4dYUOfmWna6DFccnz732n8'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 250093,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3oKMl2tJv4fdidkXUYMI5x'},
#     'href': 'https://api.spotify.com/v1/tracks/3oKMl2tJv4fdidkXUYMI5x',
#     'id': '3oKMl2tJv4fdidkXUYMI5x',
#     'is_local': False,
#     'name': 'This Love',
#     'preview_url': None,
#     'track_number': 11,
#     'type': 'track',
#     'uri': 'spotify:track:3oKMl2tJv4fdidkXUYMI5x'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 195706,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/3jBMHD19RZdAqG9iFQh7xc'},
#     'href': 'https://api.spotify.com/v1/tracks/3jBMHD19RZdAqG9iFQh7xc',
#     'id': '3jBMHD19RZdAqG9iFQh7xc',
#     'is_local': False,
#     'name': 'I Know Places',
#     'preview_url': None,
#     'track_number': 12,
#     'type': 'track',
#     'uri': 'spotify:track:3jBMHD19RZdAqG9iFQh7xc'},
#    {'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/06HL4z0CvFAxyc27GXpf02'},
#       'href': 'https://api.spotify.com/v1/artists/06HL4z0CvFAxyc27GXpf02',
#       'id': '06HL4z0CvFAxyc27GXpf02',
#       'name': 'Taylor Swift',
#       'type': 'artist',
#       'uri': 'spotify:artist:06HL4z0CvFAxyc27GXpf02'}],
#     'available_markets': ['CA', 'US'],
#     'disc_number': 1,
#     'duration_ms': 271000,
#     'explicit': False,
#     'external_urls': {'spotify': 'https://open.spotify.com/track/06WgOCf0LV2h4keYXDRnuh'},
#     'href': 'https://api.spotify.com/v1/tracks/06WgOCf0LV2h4keYXDRnuh',
#     'id': '06WgOCf0LV2h4keYXDRnuh',
#     'is_local': False,
#     'name': 'Clean',
#     'preview_url': None,
#     'track_number': 13,
#     'type': 'track',
#     'uri': 'spotify:track:06WgOCf0LV2h4keYXDRnuh'}],
#   'limit': 50,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 13},
#  'type': 'album',
#  'uri': 'spotify:album:2QJmrSgbdM35R67eoGQo4j'}
